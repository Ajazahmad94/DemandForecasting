# %%
import pandas as pd
import numpy as np
import ruptures as rpt

# %%
# Load and prepare the data for Prophet
df = pd.read_csv('/home/ajaz/DemandForecasting/Data/data.csv')
data = df.rename(columns={'TransactionDate': 'ds', 'GroupQuantity': 'y'})

# %%
# Extract 'y' column as a NumPy array
data = data['y'].values

# Apply PELT algorithm
model = "l1"  # You can choose between "l1" and "l2" cost functions
algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(data)
result = algo.predict(pen=10)

result
# Out:
# [5,
#  8,
#  12,
#  15,
#  17,
#  20,
#  23,
#  26,
#  29,
#  31,
#  33,
#  38,
#  40,
#  42,
#  47,
#  52,
#  57,
#  60,
#  63,
#  66,
#  68,
#  72,
#  76,
#  78,
#  80,
#  82,
#  86,
#  88,
#  91,
#  96,
#  98,
#  103,
#  119,
#  121,
#  128,
#  131,
#  133,
#  136,
#  148,
#  161,
#  163,
#  169,
#  171,
#  177,
#  180,
#  184,
#  187,
#  190,
#  203,
#  205,
#  208,
#  211,
#  215,
#  218,
#  224,
#  231,
#  236,
#  238,
#  243,
#  247,
#  250,
#  254,
#  257,
#  260,
#  263,
#  266,
#  270,
#  273,
#  276,
#  278,
#  281,
#  284,
#  289,
#  292,
#  294,
#  297,
#  299,
#  301,
#  306,
#  310,
#  313,
#  318,
#  320,
#  324,
#  328,
#  338,
#  341,
#  347,
#  349,
#  354,
#  356,
#  359,
#  362,
#  364,
#  370,
#  374,
#  382,
#  385,
#  392,
#  395,
#  397,
#  405,
#  407,
#  411,
#  414,
#  418,
#  429,
#  432,
#  435,
#  439,
#  442,
#  451,
#  453,
#  456,
#  460,
#  468,
#  472,
#  474,
#  476,
#  485,
#  490,
#  495,
#  501,
#  505,
#  507,
#  518,
#  523,
#  528,
#  530,
#  535,
#  540,
#  544,
#  546,
#  548,
#  554,
#  557,
#  565,
#  567,
#  578,
#  580,
#  583,
#  585,
#  591,
#  594,
#  598,
#  600,
#  602,
#  608,
#  613,
#  615,
#  623,
#  625,
#  631,
#  634,
#  637,
#  644,
#  649,
#  651,
#  667,
#  670,
#  679,
#  686,
#  688,
#  691,
#  693,
#  696,
#  698,
#  701,
#  705,
#  716,
#  719,
#  725,
#  728,
#  731,
#  733,
#  743,
#  746,
#  754,
#  760,
#  782,
#  784,
#  787,
#  789,
#  792,
#  794,
#  796,
#  798,
#  804,
#  806,
#  810,
#  813,
#  817,
#  827,
#  852,
#  872,
#  878,
#  882,
#  885,
#  887,
#  892,
#  894,
#  896,
#  900,
#  902,
#  905,
#  908,
#  912,
#  915,
#  926,
#  941,
#  946,
#  1020,
#  1030,
#  1035,
#  1043,
#  1079,
#  1082,
#  1090,
#  1093,
#  1095,
#  1097,
#  1101,
#  1104,
#  1121,
#  1146,
#  1150,
#  1152,
#  1157,
#  1159,
#  1169,
#  1176,
#  1184,
#  1198,
#  1214,
#  1217,
#  1219,
#  1226,
#  1231,
#  1233,
#  1242,
#  1249,
#  1271,
#  1288,
#  1300,
#  1342,
#  1361,
#  1363,
#  1367,
#  1370,
#  1376,
#  1381,
#  1383,
#  1385,
#  1388,
#  1391,
#  1396,
#  1399,
#  1403,
#  1405,
#  1409,
#  1412,
#  1417,
#  1419,
#  1424,
#  1426,
#  1431,
#  1437,
#  1454,
#  1458,
#  1476,
#  1481,
#  1489,
#  1491,
#  1493,
#  1495,
#  1501,
#  1503,
#  1509,
#  1514,
#  1517,
#  1520,
#  1522,
#  1525,
#  1527,
#  1536,
#  1543,
#  1545,
#  1549,
#  1551,
#  1562,
#  1573,
#  1575,
#  1584,
#  1587,
#  1590,
#  1594,
#  1596,
#  1601,
#  1612,
#  1614,
#  1627,
#  1629,
#  1632,
#  1638,
#  1643,
#  1646,
#  1649,
#  1654,
#  1657,
#  1659,
#  1661,
#  1683,
#  1701,
#  1703,
#  1706,
#  1710,
#  1725,
#  1727,
#  1731,
#  1741,
#  1747,
#  1761,
#  1765,
#  1767,
#  1770,
#  1772,
#  1788,
#  1791,
#  1802,
#  1818,
#  1823,
#  1830,
#  1832,
#  1838,
#  1844,
#  1858,
#  1860,
#  1871,
#  1888,
#  1899,
#  1907,
#  1911,
#  1920,
#  1932,
#  1940,
#  1968,
#  1980,
#  1983,
#  1993,
#  1999,
#  2003,
#  2009,
#  2027,
#  2038]

# %%
import pandas as pd
import ruptures as rpt

# Load and prepare the data for Prophet
df = pd.read_csv('/home/ajaz/DemandForecasting/Data/data.csv')
data = df.rename(columns={'TransactionDate': 'ds', 'GroupQuantity': 'y'})

# 1. Extract 'y' values as NumPy array
values = data['y'].values

# 2. Apply PELT algorithm
model = "l1"  # You can choose between "l1" and "l2" cost functions
algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(values)
#result = algo.predict(pen=10)

# 3. Map indices to dates
changepoint_dates = data['ds'].iloc[result]

# 4. Print or use the changepoint dates
#print("Changepoints (dates):", changepoint_dates)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1618, in _iLocIndexer._get_list_axis(self, key, axis)
#    1617 try:
# -> 1618     return self.obj._take_with_is_copy(key, axis=axis)
#    1619 except IndexError as err:
#    1620     # re-raise with different error message
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:971, in Series._take_with_is_copy(self, indices, axis)
#     963 """
#     964 Internal version of the `take` method that sets the `_is_copy`
#     965 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#     969 See the docstring of `take` for full explanation of the parameters.
#     970 """
# --> 971 return self.take(indices=indices, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:956, in Series.take(self, indices, axis, **kwargs)
#     954     return self.copy(deep=None)
# --> 956 new_index = self.index.take(indices)
#     957 new_values = self._values.take(indices)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:1090, in Index.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1089 if isinstance(values, np.ndarray):
# -> 1090     taken = algos.take(
#    1091         values, indices, allow_fill=allow_fill, fill_value=self._na_value
#    1092     )
#    1093 else:
#    1094     # algos.take passes 'axis' keyword which not all EAs accept
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1258, in take(arr, indices, axis, allow_fill, fill_value)
#    1256 else:
#    1257     # NumPy style
# -> 1258     result = arr.take(indices, axis=axis)
#    1259 return result
#
# IndexError: index 2038 is out of bounds for axis 0 with size 2038
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 20
#      16 algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(values)
#      17 #result = algo.predict(pen=10)
#      18
#      19 # 3. Map indices to dates
# ---> 20 changepoint_dates = data['ds'].iloc[result]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1647, in _iLocIndexer._getitem_axis(self, key, axis)
#    1645 # a list of integers
#    1646 elif is_list_like_indexer(key):
# -> 1647     return self._get_list_axis(key, axis=axis)
#    1649 # a single integer
#    1650 else:
#    1651     key = item_from_zerodim(key)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1621, in _iLocIndexer._get_list_axis(self, key, axis)
#    1618     return self.obj._take_with_is_copy(key, axis=axis)
#    1619 except IndexError as err:
#    1620     # re-raise with different error message
# -> 1621     raise IndexError("positional indexers are out-of-bounds") from err
#
# IndexError: positional indexers are out-of-bounds

# %%
# 3. Map indices to dates
changepoint_dates = data['ds'].iloc[changepoint_indices]

# 4. Print or use the changepoint dates
print("Changepoints (dates):", changepoint_dates)

# %%
# Load and prepare the data for Prophet
df = pd.read_csv('/home/ajaz/DemandForecasting/Data/data.csv')
data = df.rename(columns={'TransactionDate': 'ds', 'GroupQuantity': 'y'})

# %%
# Extract 'y' column as a NumPy array
data = data['y'].values

# Apply PELT algorithm
model = "l1"  # You can choose between "l1" and "l2" cost functions
algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(data)
result = algo.predict(pen=10)

result
# Out:
# [5,
#  8,
#  12,
#  15,
#  17,
#  20,
#  23,
#  26,
#  29,
#  31,
#  33,
#  38,
#  40,
#  42,
#  47,
#  52,
#  57,
#  60,
#  63,
#  66,
#  68,
#  72,
#  76,
#  78,
#  80,
#  82,
#  86,
#  88,
#  91,
#  96,
#  98,
#  103,
#  119,
#  121,
#  128,
#  131,
#  133,
#  136,
#  148,
#  161,
#  163,
#  169,
#  171,
#  177,
#  180,
#  184,
#  187,
#  190,
#  203,
#  205,
#  208,
#  211,
#  215,
#  218,
#  224,
#  231,
#  236,
#  238,
#  243,
#  247,
#  250,
#  254,
#  257,
#  260,
#  263,
#  266,
#  270,
#  273,
#  276,
#  278,
#  281,
#  284,
#  289,
#  292,
#  294,
#  297,
#  299,
#  301,
#  306,
#  310,
#  313,
#  318,
#  320,
#  324,
#  328,
#  338,
#  341,
#  347,
#  349,
#  354,
#  356,
#  359,
#  362,
#  364,
#  370,
#  374,
#  382,
#  385,
#  392,
#  395,
#  397,
#  405,
#  407,
#  411,
#  414,
#  418,
#  429,
#  432,
#  435,
#  439,
#  442,
#  451,
#  453,
#  456,
#  460,
#  468,
#  472,
#  474,
#  476,
#  485,
#  490,
#  495,
#  501,
#  505,
#  507,
#  518,
#  523,
#  528,
#  530,
#  535,
#  540,
#  544,
#  546,
#  548,
#  554,
#  557,
#  565,
#  567,
#  578,
#  580,
#  583,
#  585,
#  591,
#  594,
#  598,
#  600,
#  602,
#  608,
#  613,
#  615,
#  623,
#  625,
#  631,
#  634,
#  637,
#  644,
#  649,
#  651,
#  667,
#  670,
#  679,
#  686,
#  688,
#  691,
#  693,
#  696,
#  698,
#  701,
#  705,
#  716,
#  719,
#  725,
#  728,
#  731,
#  733,
#  743,
#  746,
#  754,
#  760,
#  782,
#  784,
#  787,
#  789,
#  792,
#  794,
#  796,
#  798,
#  804,
#  806,
#  810,
#  813,
#  817,
#  827,
#  852,
#  872,
#  878,
#  882,
#  885,
#  887,
#  892,
#  894,
#  896,
#  900,
#  902,
#  905,
#  908,
#  912,
#  915,
#  926,
#  941,
#  946,
#  1020,
#  1030,
#  1035,
#  1043,
#  1079,
#  1082,
#  1090,
#  1093,
#  1095,
#  1097,
#  1101,
#  1104,
#  1121,
#  1146,
#  1150,
#  1152,
#  1157,
#  1159,
#  1169,
#  1176,
#  1184,
#  1198,
#  1214,
#  1217,
#  1219,
#  1226,
#  1231,
#  1233,
#  1242,
#  1249,
#  1271,
#  1288,
#  1300,
#  1342,
#  1361,
#  1363,
#  1367,
#  1370,
#  1376,
#  1381,
#  1383,
#  1385,
#  1388,
#  1391,
#  1396,
#  1399,
#  1403,
#  1405,
#  1409,
#  1412,
#  1417,
#  1419,
#  1424,
#  1426,
#  1431,
#  1437,
#  1454,
#  1458,
#  1476,
#  1481,
#  1489,
#  1491,
#  1493,
#  1495,
#  1501,
#  1503,
#  1509,
#  1514,
#  1517,
#  1520,
#  1522,
#  1525,
#  1527,
#  1536,
#  1543,
#  1545,
#  1549,
#  1551,
#  1562,
#  1573,
#  1575,
#  1584,
#  1587,
#  1590,
#  1594,
#  1596,
#  1601,
#  1612,
#  1614,
#  1627,
#  1629,
#  1632,
#  1638,
#  1643,
#  1646,
#  1649,
#  1654,
#  1657,
#  1659,
#  1661,
#  1683,
#  1701,
#  1703,
#  1706,
#  1710,
#  1725,
#  1727,
#  1731,
#  1741,
#  1747,
#  1761,
#  1765,
#  1767,
#  1770,
#  1772,
#  1788,
#  1791,
#  1802,
#  1818,
#  1823,
#  1830,
#  1832,
#  1838,
#  1844,
#  1858,
#  1860,
#  1871,
#  1888,
#  1899,
#  1907,
#  1911,
#  1920,
#  1932,
#  1940,
#  1968,
#  1980,
#  1983,
#  1993,
#  1999,
#  2003,
#  2009,
#  2027,
#  2038]

# %%
# Apply PELT algorithm
model = "l1"  # You can choose between "l1" and "l2" cost functions
algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(data)

# %%
changepoint_dates = data['ds'].iloc[changepoint_indices]
print("Changepoints (dates):", changepoint_dates)

result = algo.predict(pen=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 changepoint_dates = data['ds'].iloc[changepoint_indices]
#       2 print("Changepoints (dates):", changepoint_dates)
#       4 result = algo.predict(pen=10)
#
# NameError: name 'changepoint_indices' is not defined

# %%
changepoint_dates = data['ds'].iloc[changepoint_indices]
print("Changepoints (dates):", changepoint_dates)

result = algo.predict(pen=10)
